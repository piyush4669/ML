# %%
#@test {"output": "ignore"}

print ('Installing dependencies...')
# !apt-get update -qq && apt-get install -qq libfluidsynth1 fluid-soundfont-gm build-essential libasound2-dev libjack-dev
# !pip install -qU pyfluidsynth pretty_midi

# Temporary hack since the colab installs a RC version of tensorflow.
# !pip uninstall -y tensorflow
# !pip install -q magenta

# Hack to allow python to pick up the newly-installed fluidsynth lib. 
# This is only needed for the hosted Colab environment.
import ctypes.util
orig_ctypes_util_find_library = ctypes.util.find_library
def proxy_find_library(lib):
  if lib == 'fluidsynth':
    return 'libfluidsynth.so.1'
  else:
    return orig_ctypes_util_find_library(lib)
ctypes.util.find_library = proxy_find_library

print ('Importing libraries and defining some helper functions...')
from google.colab import files

import magenta.music as mm
import magenta
import tensorflow

print ('🎉 Done!')
print (magenta.__version__) 
print (tensorflow.__version__)
# Out:
# Installing dependencies...

# %%
# !gsutil -q -m cp -R gs://download.magenta.tensorflow.org/models/music_vae/colab2/checkpoints/mel_2bar_big.ckpt.* /content/

# Import dependencies.
from magenta.models.music_vae import configs
from magenta.models.music_vae.trained_model import TrainedModel

# Initialize the model.
print ("Initializing Music VAE...")
music_vae = TrainedModel(
      configs.CONFIG_MAP['cat-mel_2bar_big'], 
      batch_size=4, 
      checkpoint_dir_or_path='/content/mel_2bar_big.ckpt')

print ('🎉 Done!')
# Out:
# Initializing Music VAE...
# INFO:tensorflow:Building MusicVAE model with BidirectionalLstmEncoder, CategoricalLstmDecoder, and hparams:
# {'max_seq_len': 32, 'z_size': 512, 'free_bits': 0, 'max_beta': 0.5, 'beta_rate': 0.99999, 'batch_size': 4, 'grad_clip': 1.0, 'clip_mode': 'global_norm', 'grad_norm_clip_to_zero': 10000, 'learning_rate': 0.001, 'decay_rate': 0.9999, 'min_learning_rate': 1e-05, 'conditional': True, 'dec_rnn_size': [2048, 2048, 2048], 'enc_rnn_size': [2048], 'dropout_keep_prob': 1.0, 'sampling_schedule': 'inverse_sigmoid', 'sampling_rate': 1000, 'use_cudnn': False, 'residual_encoder': False, 'residual_decoder': False}
# INFO:tensorflow:
# Encoder Cells (bidirectional):
#   units: [2048]
#
# INFO:tensorflow:
# Decoder Cells:
#   units: [2048, 2048, 2048]
#
# WARNING:tensorflow:Setting non-training sampling schedule from inverse_sigmoid:1000.000000 to constant:1.0.
# INFO:tensorflow:Restoring parameters from /content/mel_2bar_big.ckpt
# 🎉 Done!

# %%
# %pwd
# !ls
# Out:
# Classical-Piano-Composer	       sample_data
# mel_2bar_big.ckpt.data-00000-of-00001  test_output1.mid
# mel_2bar_big.ckpt.index		       test_output.mid

# %%
twink = mm.midi_file_to_note_sequence('./test_output.mid')

tea= mm.midi_file_to_note_sequence('./test_output1.mid')

# %%
print(twink)

# %%
from magenta.protobuf import music_pb2

twinkle_twinkle = music_pb2.NoteSequence()

# Add the notes to the sequence.
twinkle_twinkle.notes.add(pitch=74, start_time=0.0, end_time=0.5, velocity=90)
twinkle_twinkle.notes.add(pitch=67, start_time=0.5, end_time=1.0, velocity=90)
twinkle_twinkle.notes.add(pitch=64, start_time=1.0, end_time=1.5, velocity=90)
twinkle_twinkle.notes.add(pitch=78, start_time=1.5, end_time=2.0, velocity=90)
twinkle_twinkle.notes.add(pitch=67, start_time=2.0, end_time=2.5, velocity=90)
twinkle_twinkle.notes.add(pitch=64, start_time=2.5, end_time=3.0, velocity=90)
twinkle_twinkle.notes.add(pitch=83, start_time=3.0, end_time=3.5, velocity=90)
twinkle_twinkle.notes.add(pitch=67, start_time=3.5, end_time=4.0, velocity=90)
twinkle_twinkle.notes.add(pitch=64, start_time=4.0, end_time=4.5, velocity=90)
twinkle_twinkle.notes.add(pitch=79, start_time=4.5, end_time=5.0, velocity=90)
twinkle_twinkle.notes.add(pitch=67, start_time=5.0, end_time=5.5, velocity=90)
twinkle_twinkle.notes.add(pitch=64, start_time=5.5, end_time=6.0, velocity=90)
twinkle_twinkle.notes.add(pitch=78, start_time=6.0, end_time=6.5, velocity=90)
twinkle_twinkle.notes.add(pitch=66, start_time=6.5, end_time=7.0, velocity=90)
twinkle_twinkle.notes.add(pitch=66, start_time=7.0, end_time=7.5, velocity=90)
twinkle_twinkle.notes.add(pitch=62, start_time=7.5, end_time=8.0, velocity=90) 
twinkle_twinkle.total_time = 8

twinkle_twinkle.tempos.add(qpm=120);

# This is a colab utility method that visualizes a NoteSequence.
mm.plot_sequence(twinkle_twinkle)

# This is a colab utility method that plays a NoteSequence.
mm.play_sequence(twinkle_twinkle,synth=mm.synthesize)

# Here's another NoteSequence!
teapot = music_pb2.NoteSequence()
teapot.notes.add(pitch=73, start_time=0, end_time=0.5, velocity=90)
teapot.notes.add(pitch=47, start_time=0.5, end_time=1, velocity=90)
teapot.notes.add(pitch=39, start_time=1, end_time=1.5, velocity=90)
teapot.notes.add(pitch=71, start_time=1.5, end_time=2, velocity=90)
teapot.notes.add(pitch=47, start_time=2, end_time=2.5, velocity=90)
teapot.notes.add(pitch=39, start_time=2.5, end_time=3, velocity=90)
teapot.notes.add(pitch=75, start_time=3, end_time=3.5, velocity=90)
teapot.notes.add(pitch=46, start_time=3.5, end_time=4, velocity=90)
teapot.notes.add(pitch=42, start_time=4, end_time=4.5, velocity=90)
teapot.notes.add(pitch=63, start_time=4.5, end_time=5, velocity=90)
teapot.notes.add(pitch=42, start_time=5, end_time=5.5, velocity=90)
teapot.notes.add(pitch=39, start_time=5.5, end_time=6, velocity=90)
teapot.notes.add(pitch=68, start_time=6, end_time=6.5, velocity=90)
teapot.notes.add(pitch=47, start_time=6.5, end_time=7, velocity=90)
teapot.notes.add(pitch=47, start_time=7, end_time=7.5, velocity=90)
teapot.notes.add(pitch=76, start_time=7.5, end_time=8, velocity=90)
teapot.total_time = 8

teapot.tempos.add(qpm=120);

mm.plot_sequence(teapot)
mm.play_sequence(teapot,synth=mm.synthesize)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1392">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="009e7568-57e8-40fa-815b-bfdba89a4d7e" data-root-id="1343"></div>
# /usr/local/lib/python3.6/dist-packages/pretty_midi/instrument.py:334: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   fade_out = np.linspace(1, 0, .1*fs)
# /usr/local/lib/python3.6/dist-packages/magenta/music/notebook_utils.py:67: DeprecationWarning: encodestring() is a deprecated alias since 3.1, use encodebytes()
#   base64_wavfile=base64.encodestring(memfile.getvalue()))
# <div id="id_3"> </div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1522">Loading BokehJS ...</span>
#     </div>
# ...

# %%
import pretty_midi

pretty_midi.pretty_midi.MAX_TICK = 1e10

# We're going to interpolate between the Twinkle Twinkle Little Star
# NoteSequence we defined in the first section, and one of the generated
# sequences from the previous VAE example

# How many sequences, including the start and end ones, to generate.
num_steps = 8;

# This gives us a list of sequences.
note_sequences = music_vae.interpolate(
      twinkle_twinkle,
      teapot, 
      num_steps=8,
      length = 32)
# Concatenate them into one long sequence, with the start and 
# end sequences at each end. 
interp_seq = mm.sequences_lib.concatenate_sequences(note_sequences)

mm.play_sequence(interp_seq, synth=mm.fluidsynth)
mm.plot_sequence(interp_seq)
