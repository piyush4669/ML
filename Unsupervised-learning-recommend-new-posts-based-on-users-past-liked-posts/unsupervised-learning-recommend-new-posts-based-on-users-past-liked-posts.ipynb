# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush4669/ML/blob/master/content_recomendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from matplotlib import pyplot as plt
from numpy import unique
import random
import nltk
from IPython.display import display, HTML

# %%
#Download natural language processing data
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#import posts data
df = pd.read_csv("https://raw.githubusercontent.com/piyush4669/data/master/posts.csv").fillna("")
#import stop words for future words
stop_words = set(stopwords.words('english'))
#import stem words from nlp library for future use
stemmer = SnowballStemmer('english')

#parse dataframe for ease
post_ids = df["_id"]
post_titles = df["title"]
post_categorys = df["category"]
post_types = df["post_type"]

#delete dataframe from memory for ease
del df


clean_posts = []


#for each post title catagory and type 
for post_title, post_category, post_type in zip(post_titles, post_categorys, post_types):
    #clean up post title for punctuation and other characters and make it lowercase
    post_title = ''.join(i for i in post_title if str.isalnum(i) or i in string.whitespace).replace("  "," ").lower()
    #tokenize post title
    post_title = word_tokenize(post_title)
    #remove stop words from the post title
    post_title = [w for w in post_title if not w in stop_words]
    #convert each word with the root word by stemming
    post_title = [stemmer.stem(word) for word in post_title]
    #convert the post title back to sentence
    post_title = " ".join(post_title)
    #clean up post catagories for the same 
    post_category = post_category.replace("|", " ")
    post_category = ''.join(i for i in post_category if str.isalnum(
        i) or i in string.whitespace).replace("  ", " ").lower()
    post_category = word_tokenize(post_category)
    post_category = [w for w in post_category if not w in stop_words]
    post_category = [stemmer.stem(word) for word in post_category]
    post_category = " ".join(post_category)
    #make a sentense out of unique words from post title catagory and type
    clean_post = (post_category + " " + post_title +
                " " + post_type).replace("   ", " ")
    clean_posts.append(clean_post)

#delete unnecessary arrays to conserve memory
del post_titles, post_categorys, post_types

#print the clean post array dataset
print(*clean_posts,sep='\n')
# Out:
# plant biotechnolog hello blog
# artifici intellig machin learn inform technolog ml ai blog
# oper system oper system blog
# draw lord shiva artwork
# competit law competit law evolv blog
# competit law raghavan committe 2002 blog
# competit law let discuss case law blog
# competit law form cartel blog
# eco system biodivers blog
# econom polici econom polici blog
# graphic graphic design corpor design artwork
# draw trident artwork
# draw lord shiva artwork
# paint smart citi artwork
# pen ink om namah shivaay artwork
# draw kid buu artwork
# comput technolog inform technolog mis blog
# draw paint portrait art artwork
# competit law classifi form cartel blog
# graphic design visual art illustr graphic best friend artwork
# draw calligraphi calligraphi artwork
# photographi colour pushkar artwork
# empower marit rape rape rape blog
# photographi spiritu artwork
#  librari manag system softwar requir specif srs project
#  navig system use bfs dfs algorithm project
# draw shadow sketch artwork
# video edit promot video skill
# inorgan chemistri period tabl blog
#  comput aid machin draw camd project
# draw chosen artwork
# program languag python 3 program introduct blog
# conceptu graphic design chat app ui desgin artwork
# hr manag workforc divers challeng blog
# draw spartan artwork
# human resourc hr manag human resourc manag blog
# mass media intern relat person growth blog
# sculptur artist design contour clay artwork
# fashion design ceram artist design multipurpos jewel artwork
# craft artist design tradit modern sport artwork
# fashion design visual art conceptu artist design lgbt pride artwork
# photographi fashion design visual art graphic design artist design magazin cover redefin artwork
# fashion design visual art graphic design artist design graphic illustr virtual artwork
# mathemat linear algebra abacus blog
# electron electr technolog electr machin ai replac human intellectu work blog
# draw roman reign artwork
# draw om artwork
# draw mk sword artwork
# audit intern audit intern audit work blog
# e commerc e transact ecommerc blog
# comput technolog comput seo search engin optim blog
# audit intern financi control import intern financi control blog
# taxat custom law custom law blog
# audit audit evid audit evid necessari blog
# taxat gst good servic tax gst blog
# taxat direct tax direct tax blog
# audit secratari audit secretari audit blog
# bank bank compani role bank compani india blog
# bank bank technolog new technolog bank use today blog
# audit audit remark audit remark blog
# audit cost audit cost audit import compani blog
# audit statuari audit statutori audit blog
# photographi travel artwork
# comput technolog program languag php blog
# comput technolog program languag cnet blog
#  os project
# legal studi legal system basic structur doctrin blog
# sport coach sport law sport legisl india blog
# econom econom sociolog econom sociolog blog
# econom revenu concept concept revenu blog
# human right right duti human right duti blog
# human right right duti concept human right duti blog
# sociolog sociolog religion sociolog religion blog
# sociolog sociolog india sociolog india blog
# polit scienc intern polit intern polit blog
# polit scienc coloni india coloni india blog
# legal studi labor law labour law blog
# comput technolog design analysi algorithm program languag php variabl blog
# comput technolog comput applic program languag inform technolog oper php blog
# graphic comput creation comput graphic blog
# graphic comput creation graphic input devic blog
# e commerc onlin platform edi electron data interchang blog
# draw make joker sketch skill
# draw artist design lord shiva shadow draw artwork
# draw artist design illustr hand art artwork
# draw hand art skill
# e commerc shop platform onlin platform ecommerc busi model blog
# e commerc e transact ecash blog
#  bill calculationphp project
# comput technolog hardwar inform technolog stereoscop virtualr system blog
# comput technolog comput comput applic raster graphic system blog
# comput technolog comput printer blog
# busi busi skill busi skill blog
#  prime nophp project
#  factori nophp project
#  palindrom nophp project
#  factori net project
#  leap year check net project
#  delegatesnet project
#  overload methodnet project
# draw mahaka artwork
# comput technolog comput applic hardwar inform technolog firewal blog
# comput technolog comput applic data messag secur blog
# comput technolog mobil applic mobil comput technolog blog
# comput technolog comput applic applic mobil comput blog
# comput technolog comput applic oper system data transmiss mode blog
# comput technolog inform technolog comput applic topolog type blog
# comput technolog comput applic inform technolog baseband broadband blog
# comput technolog inform technolog comput applic inform system blog
# comput technolog comput applic inform technolog databas manag systemdbm blog
# comput technolog inform technolog ethernet blog
# draw mahaka skill
# comput technolog comput applic inform technolog network model blog
# comput technolog comput applic inform technolog decis make 7 step blog
# comput technolog comput applic inform technolog network type blog
# communic basic communiact communic blog
# comput technolog comput applic network secur threat blog
# draw morn nectar artwork
# draw hope well cake ocean artwork
# draw paint visual art graphic design print illustr girl meadow artwork
# econom revenu concept concept revenu blog
# draw visual art paint graphic design artist design illustr nerd thrown artwork
# comput technolog artifici intellig artifici intellig blog
# market advertis import digit market startup blog
# polit scienc polit thought effect leadership polit blog
# account fundament account prepar present compani final account blog
# mix media serp meta checker check meta preview serp tool search engin optim artwork
# manag team mangememnt terribl leadership influenc compani blog
# comput technolog inform technolog inform technolog blog
# busi corpor social respons millenni chang job blog
# philosophi appli ethic distract unfocus use method avoid distract blog
# human resourc perform organ organiz behaviour hr manag 5 best product web app student blog
# fashion desigin fashion textil fashion manufactur fashion techniqu garment product garment technolog textil apparel test blog
# market promot distribut decis benefit guest post writer brand blog
# biotechnolog genet engin gynecolog blog
# comput technolog mobil applic app develop blog
# physiolog neurolog studi nerv blog
# mass media indian govern corona prevent effect us blog
# physiolog osteolog skelet system blog
# physiolog cardiolog protect heart blog
# zoolog ecolog ecolog blog
# comput technolog cloud comput cloud comput blog
# physiolog radiolog radiolog blog
# comput technolog oper system oper system 1 blog
# biotechnolog molecular biolog molecular biolog blog
# physiolog gastroenterolog cardiolog watermelon lemon cooler blog
# paint quarantin day artwork
# philosophi logic sad song blog
# paint sunset ottawa artwork
# draw sketch artwork
# watercolour best place world artwork
# draw watercolour childhood sketch artwork
# draw legend artwork
# draw sort hat artwork
# mix media conceptu truth artwork
# draw paint watercolour enlighten dream artwork
# visual art gun store logo artwork
# draw calligraphi breath quarantin artwork
# conceptu art artwork
# pen ink let slide artwork
# conceptu 21 day lock quarantin artwork
# draw tea artwork
# draw late artwork
# tapestri 3d composit artwork
# calligraphi design magic happen artwork
# draw fight corona virus artwork
# human resourc perform organ person person develop affect busi leadership abil blog
# draw shiva portrait artwork
# draw insid life artwork
# comput technolog robot data scienc inform technolog artifici intellig sport look like futur blog
# comput technolog artifici intellig type ai blog
# account fundament account account financi institut blog
# philosophi public philosophi real talk blog
# digit market top 10 big benefit digit market career skill
# draw paint artwork
# photographi screw town artwork
# photographi screw2 artwork
# mass media videographi netflix case studi blog
# draw paint visual art artist design watercolour acryl meenamma artwork
# draw piglet artwork
# biotechnolog plant biotechnolog 100 free univers cours onlin 2020 blog
# sport coach sport event ipl happen year blog
# polit scienc govern polit china lie corona blog
# geographi physic geographi ozon layer heal world lockdown blog
# market promot distribut decis employe stock option buyback secur blog
# comput technolog data scienc 20 best data scienc certif cours 2020 blog
# comput technolog machin learn 7 best python data scienc cours certif 2020 blog
# mass media indian govern 7 step stay safe corona virus blog
# mass media indian govern manag stress amidst corona blog
# mass media indian govern maintain physic distanc physic distanc 101 blog
# mass media indian govern work home work corona effect blog
# graphic design diseas prevent artwork
# visual art symptom corona virus artwork
# visual art 7 step prevent covid19 artwork
# visual art break chain stop spread artwork
# visual art vaccin covid19 artwork
# visual art corona checklist artwork
# visual art handwash 101 artwork
# visual art kind corona artwork
# visual art self quarantin artwork
# graphic design visual art mask use artwork
# visual art social distanc artwork
# educ soap kill corona virus skill
# geographi physic geographi oliver mediterràni blog
# geographi physic geographi oliver mediterràni blog
# photographi aesthet artwork
# photographi quarantin artwork
# photographi bloom artwork
# photographi dog artwork
# busi busi organis way choos perfect tour travel agencycompani bhubaneswar blog
# zoolog environment biolog keep safe coronavirus blog
# human right fundament right justic north east blog
# photographi leap faith artwork
# comput technolog design analysi algorithm 8 free data scienc cours tutori 2020 blog
# busi busi organis mustvisit hill station maharashtra blog
# market market manag artifici intellig tool help get smart content market blog
# account partnership account corpor account account theori practic amalgam absorpt reconstruct compani blog
# photographi silenc shout artwork
# photographi silenc shout artwork
# busi busi organis top 10 thing someon itchi feet selfisol blog
# watercolour stone bridg full moon night artwork
# photographi night view ha penni bridg dublin ireland artwork
# legal studi incom tax law set carri forward loss blog
# graphic articul comput creation benefit virtual portfolio blog
# comput technolog machin learn 10 best artifici intellig ai cours onlin 2020 blog
# comput technolog comput applic 5 best comput network cours certif 2020 blog
# archeolog human prehistori alon univers blog
#  even odd number php project
#  armstrong noc net project
#  palindrom c net project
#  negat posit php project
#  friend number c net project
# draw creativ artwork
# busi start up entreperneurship busi strategi ventur capitalist busi plan lead startup face lose case studi blog
# geographi indian geographi mustvisit hill station maharashtra blog
# market advertis advantag onlin shop offlin shop blog
# market advertis advantag onlin shop offlin shop blog
# e commerc shop platform onlin platform digit india benefit buy groceri onlin twin citi odisha blog
# busi bioentrepreneurship choos right home clean servic provid blog
# literatur stori creativ quarantin blog
# histori indian histori आमच मबई blog
# video radio jockey skill
# photographi freez artwork
# manag busi manag spacex case studi blog
# photographi bliss artwork
# photographi sunset artwork
# photographi peac artwork
# visual art photographi grip artwork
# social work health educ import mental health blog
# social work social tech cyber world war blog
# social work human prepar better tomorrow blog
# photographi tower artwork
# photographi peac artwork
# photographi eye artwork
# photographi base imagin artwork
# photographi canon artwork
# photographi thought artwork
# photographi engross artwork
# photographi hermit artwork
# photographi innoc artwork
# photographi peac artwork
# photographi trekk artwork
# photographi portray goddess artwork
# photographi aloof artwork
# photographi deep thought artwork
# photographi monument artwork
# photographi bloom artwork
# philosophi logic thank everi second life blog
# draw time artwork
# photographi visual art aesthet artwork
# account financi account charter account see entrepreneurship trend blog
# literatur stori brother sister bond person touch blog
# psycholgi social psycholog smile often blog
# draw doodl woodl artwork
# photographi conceptu one kind artwork
# physic instrument indian space research organis isro blog
# craft work love explos box skill
# social work social intervent substanc abus think differ blog
# econom indian economi india 5 trillion economi blog
# social work substanc abus social intervent human india savior corona blog
# social work social intervent substanc abus health educ rebel blog
# social work human social intervent stand alon stand apart blog
# financ financi analysi best tool financi analysi blog
# histori indian histori interest fact india idea blog
# photographi silenc artwork
# photographi upsid artwork
# architectur beauti artwork
# photographi insect artwork
# photographi architectur paint filter artwork
# photographi street art jaisalm skill
# photographi earli morn gang artwork
# comput technolog cloud comput artifici intellig inform technolog program languag 8 best machin learn cours 2020 blog
# comput technolog design analysi algorithm web design databas manag artifici intellig 10 best ui ux design cours certif 2020 blog
# literatur movement literatur share care blog
# draw love bind artwork
# draw one worth hate artwork
# physic atom physic energi physic quantum mecahn instrument dark matter blog
# photographi aesthet artwork
# busi busi strategi ventur capitalist theori capit structur blog
# photographi conceptu vintag jaisalm real beauti rajasthan artwork
# photographi architectur illustr relax jaisalm rajasthan artwork
# photographi architectur filter busi street jaisalm raj artwork
# photographi lost artwork
# human right fundament right protect enforc format trade union blog
# environ studi pollut environment biolog light pollut solv blog
# photographi conceptu illustr q u e artwork
# photographi disappear artwork
# draw shivshakti artwork
# paint alon artwork
# physic quantum mecahn industri instrument atom physic nuclear particl physic energi physic insid black hole imag made histori blog
# paint trust artwork
# paint near natur artwork
# paint sign peac artwork
# biotechnolog environment biotechnolog keep safe coronavirus blog
# paint bird draw artwork
# photographi dream artwork
# fashion desigin pattern cultur fashion trend fashion portfoilio 7 step profession design task blog
# sketch video quick sketch gangster skull skill
# draw daaku artwork
# paint women power artwork
# draw ride artwork
# fashion desigin pattern cultur fashion textil fashion trend import design blog
# test new platform skill
# profession becom profession skill
# art make daaku art skill
# draw ganesha artwork
# draw kabir singh artwork
# art make daaku skill
# pen ink dakrai artwork artwork
# sciencetechnolog futur communic predict skill
# paint glitch artwork
# art scienc first anim post skill
# art power indian audienc skill
# paint ruin artwork
# draw form durga artwork
# fashion design illustr watercolour draw human illustr galaxi background artwork
# draw fashion design illustr watercolour human illustr background room artwork
# draw fashion design illustr watercolour human illustr artwork
# fashion design illustr watercolour fashion illustr artwork
# draw fashion design mix media conceptu illustr pen ink watercolour fashion illustr op art artwork
# fashion design illustr conceptu watercolour pen ink fashion illustr street fashion artwork
# artist design logo design graphic illustr art expo 2020 artwork
# visual art graphic design artist design graphic illustr save earth artwork
# learn alway rememb skill
# learn alway right skill
#  zerowast lifestyl project
# photographi architectur happi eidulfitr 2020 artwork
# photographi architectur visual art graphic design eid mubarak artwork
# photographi architectur visual art graphic design artist design graphic logo design eid mubarak artwork
# visual art graphic design 2d composit logo design design process artwork
# visual art photographi belief artwork
# photographi faith artwork
# photographi wave stood still artwork
# comput technolog machin learn machin learningoper mlop blog
# photographi  artwork
# photographi look natur natur artwork
# photographi keep work hard artwork
# comput technolog machin learn gan introduct blog
# comput technolog machin learn gan part2 blog
# comput technolog machin learn recommend system machin learn blog
# sociolog sociolog india reject 200 time land first job blog
# paint overcom day artwork
# mix media xbox seri x launch thousand game artwork
# artist design solarpow microbreweri designl energi sweden artwork
# comput technolog cloud comput understand cloud computingaw blog
# literatur stori fiction movement literatur 7 favourit book ive read far year blog
#  design cmos circuit boolean express microwind project
#  moor fsm sequenc detector project
#  design circular microstrip antenna project
# technolog launch ec2 instanc skill
# comput technolog data scienc integr machin learn devopsmlop blog
#  gan introduct project
#  gan introduct project
# comput technolog cloud comput aw servic launch os aw cloud blog
# comput technolog comput comput applic cloud comput cloud comput blog
# visual art calligraphi pen ink accept artwork
# mix media calligraphi pen ink voic intuit artwork
# typographi pen ink self belief artwork
# typographi pen ink reaction chang destin artwork
# typographi pen ink your hell dont stop keep move artwork
# typographi pen ink talent peopl artwork
# typographi calligraphi pen ink moment life artwork
# calligraphi typographi pen ink habit artwork
# typographi pen ink lie artwork
# calligraphi pen ink chang artwork
# typographi calligraphi pen ink fear artwork
# calligraphi typographi pen ink risk artwork
# calligraphi typographi pen ink energi artwork
# mass media media societi success stori oyo founder ritesh agarw blog
# comput technolog machin learn learn blog
# technolog aw cli setup mac skill
# comput technolog inform technolog cicd use github action blog
# comput technolog comput applic inform technolog configur docker django postgresql pgadmin elasticsearch blog
#  recommend engin project
# scienc technolog face recognit use transfer learn skill
# comput technolog comput applic inform technolog configur cicd pipelin gitlab deploy server via ssh blog

# %% [markdown]
# The above approach is taken so that we can incorporate the unique features of posts. By this method the user will be recomended based on the post as well as its catagory so the most relevent posts are available to the user in the end.

# %%
#vectorize the text data with count vectorizer method so that it can be used for clustering model.
vectorizer = TfidfVectorizer()
#get training data from the text data.
X = vectorizer.fit_transform(clean_posts)
#convert sparse matrix to dense array so that the clustering algorithm can handle it
# X = X.toarray()

# %% [markdown]
# Above we are using TFIDF for text data vectrization cause it is more reliable and widely used for text vectorization.

# %%
wcss = []
s = []

start_range = 2
end_range = 30

#training the kmeans clustering model from n=2 to n=30 centroids so that we can 
#figure out the optimal number of cluster for the given dataset

#here n_jobs with -1 will make use of all the available cores for parallelism
for i in range(start_range, end_range):
    kmeans = KMeans(n_clusters=i, init='k-means++',
                    max_iter=10, n_init=1, random_state=100,n_jobs=-1)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    s.append(round(silhouette_score(X, kmeans.labels_), 4))

#After training print the elbow graph
plt.plot(range(start_range, end_range), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()


plt.plot(range(start_range, end_range), s)
plt.title('The Silhouette Method')
plt.xlabel('Number of clusters')
plt.ylabel('silhouette_score')
plt.show()

# %% [markdown]
# **THE ELBOW METHOD**
#
# The number of clusters that we choose for a given dataset cannot be random. Each cluster is formed by calculating and comparing the distances of data points within a cluster to its centroid. An ideal way to figure out the right number of clusters would be to calculate the Within-Cluster-Sum-of-Squares (WCSS).
# WCSS is the sum of squares of the distances of each data point in all clusters to their respective centroids.
#
# We can find the optimum value for K using an Elbow point graph. We randomly initialise the K-Means algorithm for a range of K values and will plot it against the WCSS for each K value. Then figure out which elbow suits the dataset best.
#
# **THE SILHOUETTE METHOD**
#
# Silhouette analysis can be used to study the separation distance between the resulting clusters. The silhouette plot displays a measure of how close each point in one cluster is to points in the neighboring clusters and thus provides a way to assess parameters like number of clusters visually. This measure has a range of [-1, 1].

# %% [markdown]
# From the above graph results we can see that we get our best elbow at 20 clusters and similarly the Silhouette score is highest at 7 hence we can conclude that the most optimum number of clusters should be 20.

# %%
#calculate classes, centroids and distance of each post from its centroid
model = KMeans(n_clusters=100, init='k-means++', max_iter=1000, n_init=10, random_state=100,n_jobs=-1)
#train and get distance
Y = model.fit_transform(X)
#test the model on its own data to get the classes
W = model.fit(X).predict(X)
#calcuate mean distance of the post from the centroid
Y_mean = [np.mean(y) for y in Y]
#Zip results for better visualizations
result = zip(post_ids, Y_mean, W)
#sorting for better visualization
result = sorted(result, key=lambda x: x[2] + x[1])
#Print results 
print(*result,sep='\n')
# Out:
# ('5ec7abfdec493f4a26558860', 1.241353589413201, 0)
# ('5ec7a8bdec493f4a26558846', 1.2430449598109052, 0)
# ('5ec7a699ec493f4a2655883a', 1.2496866158862638, 0)
# ('5ec7a7a3ec493f4a26558840', 1.2496866158862638, 0)
# ('5ec7ad1aec493f4a26558869', 1.252331463058736, 0)
# ('5ec7aafbec493f4a26558857', 1.253147951307277, 0)
# ('5ebc3239514aab59896bcc86', 1.2613487410697983, 0)
# ('5eb1373110426255a7aa9fc1', 1.2622386205168132, 0)
# ('5e41bd7deab55d319938a839', 1.2387793288430065, 1)
# ('5e3c7293eab55d319938a74d', 1.245826052426943, 1)
# ('5e3e9cc0eab55d319938a79b', 1.2497998756424058, 1)
# ('5e37ce10eab55d319938a710', 1.2665844411079015, 90)
# ('5e4da7c8f5561b1994c8e439', 1.2652038853014884, 91)
# ('5e4dab15f5561b1994c8e446', 1.2652038853014884, 91)
# ('5e4da502f5561b1994c8e42c', 1.266315080202204, 91)
# ('5e4d359cf5561b1994c8e424', 1.2503844590469835, 92)
# ('5ea80a7e10426255a7aa9be2', 1.2587456069872922, 92)
# ('5e84a6a3a3258347b42f246e', 1.2626209652741711, 92)
# ('5e978c7ca3258347b42f2b09', 1.2628338613850507, 92)
# ('5e6eff8aed32a005135d6bb8', 1.2647197271566986, 92)
# ('5e830dc8a3258347b42f23fb', 1.2654586452755563, 92)
# ('5ea7cd9610426255a7aa9bd2', 1.265578004995948, 92)
# ('5e7a7066cfc8b713f5ac7d88', 1.2662420543290573, 92)
# ('5e7bd922cfc8b713f5ac7da9', 1.2394779123449693, 93)
# ('5e97542da3258347b42f2ae5', 1.2523556249967438, 94)
# ('5e95ed0aa3258347b42f2a0e', 1.262707421012963, 94)
# ('5eca8fceeaff6b0c3a58a3c0', 1.2597868720353445, 95)
# ('5e78c64acfc8b713f5ac7ce7', 1.2503095814884222, 96)
# ('5e901e9da3258347b42f2711', 1.2554105707891308, 97)
# ('5e901f23a3258347b42f2725', 1.2554105707891308, 97)
# ('5eaf3d4110426255a7aa9f4c', 1.265449637697995, 98)
# ('5e7220891b24db0468e90ce2', 1.265884891972978, 98)
# ('5dea816a42a8854bf6eaba89', 1.270675028945455, 98)
# ('5e776c1fcfc8b713f5ac7b23', 1.2711046399226789, 98)
# ('5dd1751db802e41ed198b680', 1.2733303564636784, 98)
# ('5e943363a3258347b42f2813', 1.244640686093817, 99)
# ('5e787636cfc8b713f5ac7cbe', 1.2552445346789884, 99)

# %%
#creating dataframe from previous result for further processing
res_df = pd.DataFrame(list(result), columns=['post_id', 'dist', 'post_class'])
#posts dataframe
post_df = pd.read_csv("https://raw.githubusercontent.com/piyush4669/data/master/posts.csv").fillna("")
#creating user-post views dataframe from file
views_df = pd.read_csv("https://raw.githubusercontent.com/piyush4669/data/master/views.csv")
#merging dataframes 
df = pd.merge(views_df, res_df, on='post_id')
#get unique users
users = df.user_id.unique().tolist()
#get all unique user data 
user_data = {}

for user in users:
    ndf = df.loc[df['user_id'] == user].values.tolist()
    user_data[user] = {}
    for row in ndf:
        # print(row[4])
        temp = str(row[4])
        if (temp in user_data[user]):
            user_data[user][temp].append(row[1])
        else:
            user_data[user][temp] = []
            user_data[user][temp].append(row[1])





#generate a random user
random_user = random.choice(users)

#get the users favourite topics
fav_class_list = list(user_data[random_user].keys())

#get user read posts
user_posts_ids = []
for fav_class in fav_class_list:
    user_posts_ids.extend(user_data[random_user][fav_class])

#get posts based on content
content_based_rec_ids = res_df.loc[res_df["post_class"].isin(
        fav_class_list)]["post_id"].values.tolist()

#get posts read by other users on the same topics
collaborative_rec_ids = df.loc[df["post_class"].isin(
    fav_class_list)]["post_id"].values.tolist()


user_posts = post_df.loc[post_df["_id"].isin(
    user_posts_ids)]

content_based_rec = post_df.loc[post_df["_id"].isin(
    content_based_rec_ids)]

collaborative_rec = post_df.loc[post_df["_id"].isin(
    collaborative_rec_ids)]

#Display result tables
print("USER LIKED POSTS")
display(HTML(user_posts.to_html()))
print("-"*150)
print("SIMILAR POSTS BASED ON USER READ POSTS")
display(HTML(content_based_rec.to_html()))
print("-"*150)
print("SIMILAR POSTS BASED ON OTHER USERS ON SAME TOPICS")
display(HTML(collaborative_rec.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>title</th>
#       <th>category</th>
#       <th>post_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>165</th>
#       <td>5e7a63c2cfc8b713f5ac7d86</td>
#       <td>Fight: Against Corona virus</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>348</th>
#       <td>5ea3227010426255a7aa9ac1</td>
#       <td>Aesthetic.</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>349</th>
#       <td>5ea3236810426255a7aa9ac8</td>
#       <td>Solitude</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>365</th>
#       <td>5eabfaf510426255a7aa9da0</td>
#       <td>Eyes that speak. Photo by Dan Farrell</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>394</th>
#       <td>5eb1df6d10426255a7aaa029</td>
#       <td>Novel &amp; Consenent (P.H.P)</td>
#       <td></td>
#       <td>project</td>
#     </tr>
#     <tr>
#       <th>395</th>
#       <td>5eb2c11210426255a7aaa052</td>
#       <td>Gangster Style</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>409</th>
#       <td>5eba2dd3514aab59896bcc57</td>
#       <td>Blur but beautiful &lt;3</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>410</th>
#       <td>5eba2e94514aab59896bcc5a</td>
#       <td>Sky never disappoints me!</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>411</th>
#       <td>5ebc3239514aab59896bcc86</td>
#       <td>The Basic Edge of Design.</td>
#       <td>Fashion Desigining|Fashion Illustration|Pattern Cutting|Fashion Communication</td>
#       <td>blog</td>
#     </tr>
#     <tr>
#       <th>415</th>
#       <td>5ec1fd0974f7660d73aa0fd5</td>
#       <td>Daaku</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>416</th>
#       <td>5ec2215374f7660d73aa1011</td>
#       <td>Women power</td>
#       <td>Painting</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>421</th>
#       <td>5ec2f7c074f7660d73aa116e</td>
#       <td>Making of Daaku Art</td>
#       <td>Art</td>
#       <td>skill</td>
#     </tr>
#     <tr>
#       <th>423</th>
#       <td>5ec3676574f7660d73aa119a</td>
#       <td>Kabir singh</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>430</th>
#       <td>5ec57acaf2781131cc7e51d5</td>
#       <td>Ruins.</td>
#       <td>Painting</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>431</th>
#       <td>5ec601a0f2781131cc7e522e</td>
#       <td>Form of ma durga</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>432</th>
#       <td>5ec7a699ec493f4a2655883a</td>
#       <td>HUMAN ILLUSTRATION (With Galaxy Background)</td>
#       <td>Fashion Design|Illustration|Watercolours|Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>433</th>
#       <td>5ec7a7a3ec493f4a26558840</td>
#       <td>HUMAN ILLUSTRATION ( Background of a room)</td>
#       <td>Drawings|Fashion Design|Illustration|Watercolours</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>434</th>
#       <td>5ec7a8bdec493f4a26558846</td>
#       <td>HUMAN ILLUSTRATION</td>
#       <td>Drawings|Fashion Design|Illustration|Watercolours</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>435</th>
#       <td>5ec7aafbec493f4a26558857</td>
#       <td>FASHION ILLUSTRATION</td>
#       <td>Fashion Design|Illustration|Watercolours</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>436</th>
#       <td>5ec7abfdec493f4a26558860</td>
#       <td>FASHION ILLUSTRATION (OP ART)</td>
#       <td>Drawings|Fashion Design|Mixed Media|Conceptual|Illustration|Pen and ink|Watercolours</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>437</th>
#       <td>5ec7ad1aec493f4a26558869</td>
#       <td>FASHION ILLUSTRATION (street fashion)</td>
#       <td>Fashion Design|Illustration|Conceptual|Watercolours|Pen and ink</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>438</th>
#       <td>5ec8204cec493f4a26558893</td>
#       <td>Art Expo 2020</td>
#       <td>Artistic design|Logo Design|Graphic|Illustration</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>439</th>
#       <td>5ec821ddec493f4a2655889e</td>
#       <td>Save Earth.</td>
#       <td>Visual Arts|Graphic Design|Artistic design|Graphic|Illustration</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>441</th>
#       <td>5eca7601ec493f4a26558a62</td>
#       <td>Always do Right 👍🏻</td>
#       <td>Learning</td>
#       <td>skill</td>
#     </tr>
#     <tr>
#       <th>442</th>
#       <td>5eca8fceeaff6b0c3a58a3c0</td>
#       <td>Zero-Waste Lifestyle</td>
#       <td></td>
#       <td>project</td>
#     </tr>
#     <tr>
#       <th>448</th>
#       <td>5ecc1d4eeaff6b0c3a58a565</td>
#       <td>Faith in yourself</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>449</th>
#       <td>5ecce8a5eaff6b0c3a58a5e9</td>
#       <td>The Waves Have Stood Still</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>450</th>
#       <td>5ecd5d417023451e662235c5</td>
#       <td>Machine Learning”&amp;“Operations" (MlOps)</td>
#       <td>Computer Technology|Machine Learning</td>
#       <td>blog</td>
#     </tr>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>title</th>
#       <th>category</th>
#       <th>post_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>5da745b6019399436815c4cd</td>
#       <td>Corporate design</td>
#       <td>Graphic|Graphic Design</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>5dada695610ba040fbfdf585</td>
#       <td>Trident</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>5dada798610ba040fbfdf58b</td>
#       <td>Smart City</td>
#       <td>Painting</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>5dada89b610ba040fbfdf591</td>
#       <td>Kid Buu</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>5dbc622a99cbb90e4339c7f6</td>
#       <td>Best friend</td>
#       <td>Graphic Design|Visual Arts|Illustration|Graphic</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>5dde6a91369b28584ecca156</td>
#       <td>Spirituality</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>5de179d80eb5e25a8a07f079</td>
#       <td>Navigation system using BFS DFS algorithms</td>
#       <td></td>
#       <td>project</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>5dee9b5042a8854bf6eabaaf</td>
#       <td>Computer Aided Machine Drawing (CAMD)</td>
#       <td></td>
#       <td>project</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>5df64ad1cc709107827fb3dd</td>
#       <td>The Chosen</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>5e1029f22a37d20505da2a79</td>
#       <td>Chat App UI Desgin</td>
#       <td>Conceptual|Graphic Design</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>5e281cf0025ae20886de2050</td>
#       <td>Spartan</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>5e2d3fbfc85ab714a7da66d5</td>
#       <td>Multipurpose Jewel</td>
#       <td>Fashion Design|Ceramics|Artistic design</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>5e2d4737c85ab714a7da66d9</td>
#       <td>LGBT PRIDE</td>
#       <td>Fashion Design|Visual Arts|Conceptual|Artistic design</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>5e2d4d63c85ab714a7da66db</td>
#       <td>Magazine Cover Redefined</td>
#       <td>Photography|Fashion Design|Visual Arts|Graphic Design|Artistic design</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>5e2d516fc85ab714a7da66dd</td>
#       <td>'The Virtual ME'</td>
#       <td>Fashion Design|Visual Arts|Graphic Design|Artistic design|Graphic|Illustration</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>5e36746a8d344822fed4d147</td>
#       <td>ROMAN REIGNS</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>5e3674c68d344822fed4d152</td>
#       <td>OM</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>5e36763d8d344822fed4d15d</td>
#       <td>MK Swords</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td
td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>152</th>
#       <td>5e79b32ecfc8b713f5ac7d3f</td>
#       <td>The legend</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>153</th>
#       <td>5e79b8becfc8b713f5ac7d45</td>
#       <td>The sorting hat</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>5e79f3fccfc8b713f5ac7d54</td>
#       <td>The Enlightened Dreams</td>
#       <td>Drawings|Painting|Watercolours</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>161</th>
#       <td>5e7a60edcfc8b713f5ac7d82</td>
#       <td>Tea!</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>162</th>
#       <td>5e7a614fcfc8b713f5ac7d83</td>
#       <td>You are late.</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>165</th>
#       <td>5e7a63c2cfc8b713f5ac7d86</td>
#       <td>Fight: Against Corona virus</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>174</th>
#       <td>5e7de48ca3258347b42f2110</td>
#       <td>Painting</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>175</th>
#       <td>5e7df068a3258347b42f2125</td>
#       <td>screw town</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>176</th>
#       <td>5e7df283a3258347b42f2128</td>
#       <td>screw2</td>
#       <td>Photography</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>178</th>
#       <td>5e7f39a3a3258347b42f2151</td>
#       <td>The Meenamma</td>
#       <td>Drawings|Painting|Visual Arts|Artistic design|Watercolours|Acrylics</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>179</th>
#       <td>5e7f3cf8a3258347b42f2154</td>
#       <td>Piglet</td>
#       <td>Drawings</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>191</th>
#       <td>5e81bf2fa3258347b42f2244</td>
#       <td>Disease Prevention</td>
#       <td>Graphic Design</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>192</th>
#       <td>5e81bf73a3258347b42f2257</td>
#       <td>Symptoms of Corona Virus</td>
#       <td>Visual Arts</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>200</th>
#       <td>5e81c257a3258347b42f22f0</td>
#       <td>Mask: When to use it</td>
#       <td>Graphic Design|Visual Arts</td>
#       <td>artwork</td>
#     </tr>
#     <tr>
#       <th>202</th>
#       <td>5e822b4aa3258347b42f235f</td>
#       <td>How Soap Kills Corona Virus</td>
#       <td>Education</td>
#       <td>skill</td>
#     </tr>
#     <tr>
#       <th>205</th>
#       <td>5e8307a

# %% [markdown]
# **CONCLUSION**
#
# The above implementation for Content Based Filtering and Collaborative Filtering is based on clustering algorithm (Kmeans), In this i tried to minimize the use of machine learning algorithms to just once and aimed to derive all of the required results from that.
#
# This is done so that a lot of computation time can be saved in producton and the response can be faster and efficient. Due to this we need to run this model when a new post is uploaded and we can infer results for each user via same result.
#
# For Content Based Filtering first the post data is cleaned and reorganised, vectorized and is clustered based on the most optimum number of clusters infered from testing. The clusters represent a Point of Interest of a user, if a user is interested in any post of a particular cluster the user will very likely to have interest in the other posts of the same cluster and hence those post can be recomended. The posts in a cluster are also weighted and hence can be chosen as per priority of interest.
#
# The Collaborative Recommendation works based on which posts are most populer among users, if for example a user is interested in posts from a specific cluster then its very likely that he will be interested in the posts read by others from the same cluster and hence can be recomended. These posts have higher weightage then Content Based Filtering posts and can shown at the top for priority.
#
# ##The key property of this implementation is that it will work perfectly even if certain features are missing such as either catagory, title or post-type. It will provide the result with whats present instead of disregarding the N/A values.
#
# NOTE: In nearly all cases the content filtering and collaborative filtering are same cause almost all the posts are read by some or the another user hence total posts remomended are total posts avalable in this case. In reality this can be overcome by comparing the read scores and present only the top posts or by only selecting a handfull of users instead of all the users present.
#
# I will be very grateful for any feedback or report on my work, if any mistakes conceptual or code related are discoved plese report it back.
